# %% [markdown]
# <h1>Clean CSV Data and Add to SQL Database</h1>

# %% [markdown]
# <h4>Import Dependencies</h4>

# %%
import os
import csv
import pandas as pd

import sqlite3
import csv
from sqlalchemy import create_engine

from config import pgPassword

# %% [markdown]
# <h4>Create paths to CSV files</h4>

# %%
pathBeers = os.path.join("data", "beers.csv")
pathBreweries = os.path.join("data", "breweries.csv")
pathOpenBeer = os.path.join("data", "open-beer-database.csv")
pathRecipe = os.path.join("data", "recipeData.csv")

# %% [markdown]
# <h4>Load Beer file into DataFrame and clean</h4>

# %%
beersDF = pd.read_csv(pathBeers)
beersDF = beersDF.drop_duplicates(subset=['id'])
beersDF.sort_values(by=["id"]).head()
# Out:
#       Unnamed: 0    abv    ibu  id                      name  \
# 1583        1583  0.065   65.0   1           Dale's Pale Ale
# 1582        1582  0.087   85.0   4         Gordon Ale (2009)
# 1581        1581  0.080   35.0   5                  Old Chub
# 1580        1580  0.099  100.0   6        GUBNA Imperial IPA
# 1579        1579  0.053   35.0   7  Mama's Little Yella Pils
#
#                                style  brewery_id  ounces
# 1583         American Pale Ale (APA)         166    12.0
# 1582  American Double / Imperial IPA         166    12.0
# 1581                    Scottish Ale         166    12.0
# 1580  American Double / Imperial IPA         166    12.0
# 1579                  Czech Pilsener         166    12.0

# %% [markdown]
# <h4>Load Breweries file into DataFrame and clean</h4>

# %%
breweriesDF = pd.read_csv(pathBreweries)
breweriesDF = breweriesDF.rename(columns={"Unnamed: 0": "id"})
breweriesDF = breweriesDF.drop_duplicates(subset=['id'])
breweriesDF.head(167)
# Out:
#       id                       name           city state
# 0      0         NorthGate Brewing     Minneapolis    MN
# 1      1  Against the Grain Brewery     Louisville    KY
# 2      2   Jack's Abby Craft Lagers     Framingham    MA
# 3      3  Mike Hess Brewing Company      San Diego    CA
# 4      4    Fort Point Beer Company  San Francisco    CA
# ..   ...                        ...            ...   ...
# 162  162        Right Brain Brewery  Traverse City    MI
# 163  163    Sly Fox Brewing Company   Phoenixville    PA
# 164  164         Round Guys Brewing       Lansdale    PA
# 165  165     Great Crescent Brewery         Aurora    IN
# 166  166        Oskar Blues Brewery       Longmont    CO
#
# [167 rows x 4 columns]

# %% [markdown]
# <h4>Load OpenBeer file into DataFrame and clean</h4>

# %%
openBeerDF = pd.read_csv(pathOpenBeer)
targetColumns = ["Name", "id", "Alcohol_By_Vol", "International_Bitterness_Units", "Style", "style_id", "Category","Brewer","brewery_id", "Address", "City", "State", "Country", "Coordinates"]
openBeerDF = openBeerDF[targetColumns]
openBeerDF = openBeerDF.drop_duplicates(subset=['id'])
openBeerDF.sort_values(by=["id"]).head()
# Out:
#                         Name  id  Alcohol_By_Vol  \
# 391              Hocus Pocus   1               5
# 473        Grimbergen Blonde   2               7
# 2937  Widdershins Barleywine   3               9
# 2938                 Lucifer   4               9
# 2082                  Bitter   5               4
#
#       International_Bitterness_Units                              Style  \
# 391                                0  Light American Wheat Ale or Lager
# 473                                0                                 na
# 2937                               0                                 na
# 2938                               0                                 na
# 2082                               0                                 na
#
#       style_id     Category                     Brewer  brewery_id  \
# 391        116  Other Style                  Magic Hat         812
# 473         -1           na       Brouwerij Alken-Maes         264
# 2937        -1           na  Left Hand Brewing Company         779
# 2938        -1           na         Brouwerij Liefmans         287
# 2082        -1           na           Ridgeway Brewing        1056
#
#                   Address              City            State         Country  \
# 391   5 Bartlett Bay Road  South Burlington          Vermont   United States
# 473         Rue Derbque 7             Jumet          Hainaut         Belgium
# 2937   1265 Boston Avenue          Longmont         Colorado   United States
# 2938      200 Aalststraat        Oudenaarde  Oost-Vlaanderen         Belgium
# 2082       6 Chapel Close       South Stoke           Oxford  United Kingdom
#
#             Coordinates
# 391   44.4284, -73.2131
# 473     50.4431, 4.4147
# 2937  40.1587, -105.113
# 2938     50.8439, 3.617
# 2082   51.5462, -1.1355

# %% [markdown]
# <h4>Load Recipe file into DataFrame and clean</h4>

# %%
recipesDF = pd.read_csv(pathRecipe, encoding = "ISO-8859-1")
recipesDF = recipesDF[["BeerID", "Name", "Style", "StyleID","OG", "FG", "ABV","IBU", "Color", "Efficiency", "BrewMethod" ]]
recipesDF = recipesDF.drop_duplicates(subset=['BeerID'])
recipesDF.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                 Style  StyleID     OG     FG   ABV    IBU  \
# 0                           Cream Ale       45  1.055  1.013  5.48  17.65
# 1  Holiday/Winter Special Spiced Beer       85  1.083  1.021  8.16  60.65
# 2                        American IPA        7  1.063  1.018  5.91  59.25
# 3                        American IPA        7  1.061  1.017  5.80  54.48
# 4                   Belgian Blond Ale       20  1.060  1.010  6.48  17.84
#
#    Color  Efficiency BrewMethod
# 0   4.83        70.0  All Grain
# 1  15.64        70.0  All Grain
# 2   8.98        70.0    extract
# 3   8.50        70.0  All Grain
# 4   4.57        72.0  All Grain

# %% [markdown]
# <h4>Create a connection to SQL database</h4>

# %%
pg_user = 'postgres'
pg_password = 'Nathan@2020'
db_name = 'beersDB'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# []

# %% [markdown]
# <h4>Add dataframes to SQL database</h4>

# %%
beersDF.to_sql(name = "beers", con=engine, if_exists='append', index=False)

# %%
breweriesDF.to_sql(name = "breweries", con=engine, if_exists='append', index=False)

# %%
openBeerDF.to_sql(name = "openBeer", con=engine, if_exists='append', index=False)

# %%
recipesDF.to_sql(name = "recipes", con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['beers', 'breweries', 'openBeer', 'recipes']

# %%
pd.read_sql_query('select * from beers', con=engine).head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %% [markdown]
# <h4>Pull SQL table back into DataFrame</h4>

# %%
newBeerDF = pd.read_sql_table('beers', con=engine)
newBeerDF.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %% [markdown]
# <h4>Convert Dataframe to Dictionary</h4>

# %%
newBeerDict = newBeerDF.to_dict('records')
print(newBeerDict[0])
# Out:
# {'Unnamed: 0': 0, 'abv': 0.05, 'ibu': nan, 'id': 1436, 'name': 'Pub Beer', 'style': 'American Pale Lager', 'brewery_id': 408, 'ounces': 12.0}

# %%
beersAndBreweries = pd.merge(left = beersDF, right = breweriesDF, how="inner", left_on="brewery_id", right_on = "id")
beersAndBreweries = beersAndBreweries[["name_x", "style", "name_y", "abv", "ibu"]]
beersAndBreweries = beersAndBreweries.rename(columns = {"name_x": "beer",
                                                       "name_y": "brewery"})
beersAndBreweries.head()

breweryLocations = openBeerDF[["Brewer", "Address", "City", "State", "Country", "Coordinates"]]

joinedDF = pd.merge(left = breweryLocations, right = beersAndBreweries, how="inner", left_on="Brewer", right_on = "brewery")

noNulls = joinedDF.dropna().drop_duplicates()

noNulls.head()
# Out:
#                   Brewer                   Address         City  \
# 15      Carolina Brewery  460 West Franklin Street  Chapel Hill
# 27  Breckenridge Brewery       471 Kalamath Street       Denver
# 28  Breckenridge Brewery       471 Kalamath Street       Denver
# 29  Breckenridge Brewery       471 Kalamath Street       Denver
# 30  Breckenridge Brewery       471 Kalamath Street       Denver
#
#              State        Country        Coordinates              beer  \
# 15  North Carolina  United States  35.9103, -79.0632    Santa's Secret
# 27        Colorado  United States  39.7236, -105.001       Agave Wheat
# 28        Colorado  United States  39.7236, -105.001  SummerBright Ale
# 29        Colorado  United States  39.7236, -105.001       Lucky U IPA
# 30        Colorado  United States  39.7236, -105.001     Avalanche Ale
#
#                        style               brewery    abv   ibu
# 15             Winter Warmer      Carolina Brewery  0.059  22.0
# 27   American Pale Wheat Ale  Breckenridge Brewery  0.042   9.0
# 28   American Pale Wheat Ale  Breckenridge Brewery  0.045  15.0
# 29              American IPA  Breckenridge Brewery  0.062  68.0
# 30  American Amber / Red Ale  Breckenridge Brewery  0.054  19.0

# %%
recipesDF.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
